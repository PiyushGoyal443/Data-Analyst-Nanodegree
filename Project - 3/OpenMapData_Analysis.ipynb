# %% [markdown]
# # OpenStreetMap Data Wrangling
#
# *By Piyush Goyal*
#
# Map Area : [Los Angeles, California](https://s3.amazonaws.com/metro-extracts.mapzen.com/los-angeles_california.osm.bz2)
#
# ## Problems :
#
#
# 1. Section 1: [Data Auditing and Data Cleaning](#Section-1-:-Data-auditing-and-data-cleaning)
#   * [Tag and keys count](#1.1-Tags-and-keys-counts)
#   * [Special 'tag' keys values](#1.2-Special-'tag'-keys-values)
#   * [Multiple Zip Codes](#1.3-Multiple-Zip-Codes)
#   * [Phone Numbers](#1.4-Phone-Numbers)
#   * [Street Names Abbreviated](#Street-Names-Abbreviated)
#
#
# 2. Section 2: [Data Overview](#Section-2:-Data-Overview)
#   * [File Sizes](#File-Sizes)
#   * [Number of Documents](#Number-of-Documents)
#   * [Number of nodes and ways](#Number-of-nodes-and-ways)
#   * [Number of distinct users](#Number-of-distinct-users)
#   * [Top 10 Contributing Users](#Top-10-Contributing-Users)
#   * [Number of users contributing only once](#Number-of-users-contributing-only-once)
#
#
# 3. Section 3: [Additional Ideas](#Section-3:-Additional-Ideas)
#   * [Contributor statistics](#Contributor-statistics)
#   * [Conclusion](#Conclusion)

# %% [markdown]
# ### Section 1 : Data auditing and data cleaning

# %%
# coding=utf8
# -*- coding: utf8 -*-

# %%
# imports
import json
import xml.etree.cElementTree as ET
import codecs
import pymongo
import re
from collections import defaultdict
from pprint import pprint
import operator
import phonenumbers
import pymongo

# %%
# required variable declarations
__JSONFILE__ = 'los-angeles_california.osm.json'
__OSMFILE__ = 'los-angeles_california.osm'

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
address_regex = re.compile(r'^addr\:')
street_regex = re.compile(r'^street')
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

# %% [markdown]
# #### 1.1 Tags and keys counts

# %%
def count_tags(osmfile):
    tag_counts = defaultdict(int)
    tag_keys = defaultdict(int)
    
    for _, element in ET.iterparse(osmfile, ('start',)):
        tag_counts[element.tag] += 1
        
        if element.tag == 'tag' and 'k' in element.attrib: 
            tag_keys[element.get('k')] += 1

        element.clear()
        
    return tag_counts, tag_keys

# %%
tag_counts, tag_keys = count_tags(__OSMFILE__)

# to print the count of each tag present
pprint(dict(tag_counts))

# %%
# to print the count of each key in 'tag' tag
pprint(sorted(tag_keys.items(), key = operator.itemgetter(1))[::-1][:20])
# Out:
# [('building', 670742),
#  ('highway', 566014),
#  ('ele', 484618),
#  ('height', 470715),
#  ('lacounty:bld_id', 469648),
#  ('lacounty:ain', 469468),
#  ('start_date', 443346),
#  ('building:units', 422001),
#  ('name', 380151),
#  ('tiger:county', 243155),
#  ('tiger:cfcc', 242914),
#  ('source', 226421),
#  ('tiger:name_base', 225098),
#  ('tiger:name_type', 203989),
#  ('tiger:zip_left', 185387),
#  ('tiger:zip_right', 179588),
#  ('tiger:reviewed', 121028),
#  ('tiger:source', 112912),
#  ('tiger:tlid', 112329),
#  ('tiger:separated', 106620)]

# %% [markdown]
# From above we see the top 20 of the most frequent keys occuring in 'tag' tags.

# %%
def write_key_data(osmfile, tag_keys):
    """
    Parses osm file and writes the maximum of 20 data of each tag with kay-value pairs into json file
    """
    data = defaultdict(set)
    
    tag_keys = dict(tag_keys).keys()
    for _,element in ET.iterparse(osmfile, ('start',)):
        if element.tag == 'note' or element.tag == 'way':
            
            for tag in element.iter('tag'):
                if 'k' in tag.attrib and 'v' in tag.attrib:
                    key = tag.get('k')
                    if key in tag_keys and len(data[key]) < 20:
                        data[key].add(tag.get('v'))
        element.clear()
    
    #converting data so that it is json serializable
    for key in data.keys():
        data[key] = list(data[key])
    
    with open(osmfile+'-tag-key-data.json','w') as fo:
        fo.write(json.dumps(data, indent=4)+"\n")

# %%
write_key_data(__OSMFILE__,tag_keys)

# %% [markdown]
# After getting the count of key occuring, to know what each key hold and what the value means, I wrote maximum of 20 values of each key into a json file. This gave insight of some inconsistant data format (like 40mph vs 40).

# %% [markdown]
# #### 1.2 Special 'tag' keys values

# %%
unique_keys_count = 0
for key in tag_keys.keys():
    if tag_keys[key] == 1:
        unique_keys_count += 1

# %%
print unique_keys_count
# Out:
# 704

# %% [markdown]
# So there were **704** tags with count equal 1 from which some were very specific while some were not necessary. So I manually made list of keys which are to be filter out before populating the databasewhich also contained some key-value tags with count more than 1 which has redundant data.

# %% [markdown]
# #### 1.3 Multiple Zip Codes
#
# On observing the data, the zip codes were mapped to multiple keys (eg. tiger:zip_left, tiger:zip_right, etc) and also in all some of the keys multiple zip codes were present with ';' as a delimeter.

# %% [markdown]
# #### 1.4 Phone Numbers
#
# Phone numbers were formatted inconsistantly. It contained values like 'yes', so all these values were ignored and the all phone numbers were reformatted to standard form (951) 587 2505 using [phonenumbers](https://pypi.python.org/pypi/phonenumbers) module in python

# %%
expected = ["Rapid", "Ridge", "Hills", "Bottom", "Union", "Brook", "Causeway", "Heights", "Station", "Hill",
            "Branch", "Lodge", "Rue", "Isle", "Burg", "River", "Mews", "Views", "Dam", "Cove", "Brooks",
            "Motorway", "Ways", "Throughway", "Road", "Ridges", "Path", "Haven", "Key", "Island", "Camp", 
            "Extensions", "Pine", "Ferry", "Passage", "Ports", "Spurs", "Ville", "Forges", "Valleys", "Creek",
            "Terrace", "Alley", "Course", "Prairie", "Corner", "Mill", "Glen", "Arcade", "Mills", "Plains",
            "Rest", "Bypass", "Circle", "Walk", "Circles", "Flat", "Junction", "Extension", "Park", "Lakes",
            "Ford", "Orchard", "Grove", "Courts", "Fords", "Walks", "Cape", "Landing", "Spur", "Fort",
            "Greens", "Harbor", "Light", "Plaza", "Coves", "Mall", "Green", "Islands", "Loop", "Overpass",
            "Square", "Meadow", "Stream", "Point", "Pines", "Viaduct", "Shore", "Shoal", "Pass", "Roads",
            "Place", "Glens", "Centers", "Row", "Mountain", "Boulevard", "Underpass", "Inlet", "Bayoo",
            "Lights", "Unions", "Forest", "Way", "Knoll", "Court", "Stravenue", "Crossroad", "Crest",
            "Meadows", "Tunnel", "Dale", "Mountains", "Keys", "Parkways", "Drives", "Trail", "Skyway", 
            "Pike", "Lane", "Land", "Center", "Corners", "Mount", "Ramp", "Points", "Shores", "Turnpike",
            "Flats", "Parkway", "Plain", "Loaf", "Divide", "Wall", "Streets", "Hollow", "Locks", "Canyon",
            "Spring", "Oval", "Avenue", "Junctions", "Vista", "Burgs", "Valley", "Lake", "Parks", "Field",
            "Forge", "Expressway", "Beach", "Forks", "Harbors", "Neck", "Squares", "Garden", "Manor",
            "Annex", "Club", "Villages", "Bluffs", "Wells", "Falls", "Highway", "Bluff", "Fall", "Cliff",
            "Fork", "Knolls", "Fields", "Route", "Ranch", "Curve", "Drive", "Trafficway", "Freeway",
            "Groves", "Estates", "Common", "Radial", "Crossing", "Run", "Summit", "Cliffs", "Manors",
            "Gardens", "View", "Bridge", "Trace", "Estate", "Rapids", "Well", "Lock", "Shoals",
            "Mission", "Port", "Track", "Street", "Bend", "Village", "Springs", "Crescent", "Gateway"]

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
        elem.clear()
    osm_file.close()
    return street_types

def test():
    st_types = audit(__OSMFILE__)
    pprint(dict(st_types))
    print len(st_types)

if __name__ == '__main__':
    test()
# Out:
# {'100': set(['3347 Michelson Dr Suite 100']),
#  '102': set(['Park Point #102']),
#  '103': set(['Ford  Street, Ste. 103', 'Vista Ave, Suite 103']),
#  '104': set(['4121 Brockton Ave., Suite 104', 'Ventura Boulevard #104']),
#  '106': set(['South Lake Ave #106', 'Ventura Boulevard #106']),
#  '1101': set(['15th Street Ste. 1101']),
#  '110402': set(['9th St, Unit 110402']),
#  '115': set(['4th Street Suite 115']),
#  '118': set(['Ventura Boulevard #118']),
#  '1180': set(['Santa Monica Boulevard, Suite 1180']),
#  '119': set(['North Topanga Canyon Boulevard #119', 'Ventura Boulevard #119']),
#  '12': set(['Telephone Ave Suite 12']),
#  '120': set(['Ventura Blvd #120']),
#  '1216': set(['Laurel Canyon Blvd. #1216']),
#  '138': set(['14757 State Hwy 138',
#              'CA 138',
#              'N. Highway 138',
#              'State Highway 138']),
#  '14': set(['20100 West San Fernando Road (1260) E Of Sr 14',
#             '20516 West San Fernando Road W Of Sr 14',
#             '23610 West San Fernando Road 1/2 Mi W Of Sr 14',
#             'W Ave S @ Geiger Ave W Of Sr 14']),
#  '150': set(['Chino Avenue Suite 150', 'Highway 189, Suite 150']),
#  '162': set(['S Lemon Ave #162']),
#  '17': set(['North Vermont Avenue Unit #17']),
#  '1725': set(['1725']),
#  '18': set(['28712 Hwy 18', 'Hwy 18']),
#  '189': set(['Highway 189', 'State Highway 189']),
#  '200': set(['North Camden Drive, Suite 200', 'Winchester Rd #200']),
#  '2004': set(['9th Street, #2004']),
#  '203': set(['E Ontario Ave #203']),
#  '203A': set(['Bolsa Avenue Suite 203A']),
#  '204': set(['416 N Bedford Dr #204']),
#  '208': set(['Ventura Boulevard #208']),
#  '21': set(['South Avenue 21']),
#  '230': set(['Newport Center Drive Ste. 230']),
#  '243': set(['State Highway 243']),
#  u'246-0756': set([u'Greenleaf Gourmet Chopshopmore info\u200e9671 Wilshire BoulevardBeverly Hills, CA 90212  (310) 246-0756']),
#  '26': set(['Vista Del Lago # 26']),
#  '26705': set(['26705']),
#  '273': set(['Deep Valley Drive #273']),
#  u'276-1562': set([u'Subwaymore info\u200e9673 Wilshire BoulevardBeverly Hills, CA 90212 (310) 276-1562']),
#  '30.12': set(['Hwy 33 PM 30.12']),
#  '300': set(['Olive Avenue, # 300']),
#  u'308': set([u'499 North Ca\xf1on Drive, Suite 308']),
#  '309': set(['Ventura Blvd #309']),
#  '31': set(['5349 Newcastle Avenue #31']),
#  '31.7': set(['SR 15 PM 31.7']),
#  '3190': set(['W Jefferson Blvd Suite 3190']),
#  '38': set(['37710 Hwy 38']),
#  '38.3': set(['LA 2 PM 38.3']),
#  '39': set(['SR 18 PM 39']),
#  '39.84': set(['13693 Mariposa Rd I 15  PM 39.84']),
#  '395': set(['8701 Hwy 395',
#              'Highway 395',
#              'North Highway 395',
#              'North Old Highway 395',
#              'Old Highway 395',
#              'South Old Highway 395',
#              'State Highway 395']),
#  '3A': set(['Traction Avenue, Suite 3A']),
#  '3rd': set(['E. 3rd']),
#  '426': set(['5250 W. Century Blvd Suite 426']),
#  '443': set(['PO Box 443']),
#  '46.8': set(['Hwy 14 PM 46.8']),
#  '5': set(['West 9th Street #5']),
#  '503': set(['503']),
#  '52': set(['Avenue 52']),
#  '53': set(['N Avenue 53']),
#  '54.6': set(['Hwy 14 PM 54.6']),
#  '56': set(['N Avenue 56']),
#  '57': set(['Pathfinder Rd @ Sr 57']),
#  '6': set(['East Miraloma Avenue Unit 6']),
#  '61': set(['North Avenue 61']),
#  '61.8': set(['Hwy 2 PM 61.8']),
#  '64': set(['Avenue 64', 'North Avenue 64']),
#  '66': set(['Route 66']),
#  '76': set(['Highway 76', 'Hwy 76', 'State Route 76']),
#  u'777-5877': set([u'Barney Greengrass Restaunt, \u200e9570 Wilshire Boulevard Beverly Hills, CA 90212 (310) 777-5877']),
#  '79': set(['Highway 79']),
#  u'858-1383': set([u"Capriotti'smore info\u200e9683 Wilshire BoulevardBeverly Hills, CA 90212(310) 858-1383"]),
#  '900': set(['E First St #900']),
#  '90815': set(['90815']),
#  '92627': set(['Newport Blvd, Costa Mesa, CA 92627']),
#  'A': set(['2111 Iowa Ave Unit A',
#            'Avenue A',
#            'Santa Monica Boulevard #A',
#            'Silver Spur Road #A',
#            'Via Estrada, Unit A',
#            'Western Ave # A']),
#  'A2': set(['2801 W Macarthur Blvd A2']),
#  'Aberdeen': set(['Aberdeen']),
#  'Abeto': set(['Abeto', 'Paseo Abeto']),
#  'Acquaviva': set(['Via Acquaviva']),
#  'Acres': set(['Glen Acres']),
#  'Ada': set(['Ada']),
#  'Aguacate': set(['Via del Aguacate']),
#  'Aguilar': set(['Aguilar']),
#  'Aims': set(['Aims']),
#  'Alameda': set(['La Alameda', 'West Alameda']),
#  'Alamitos': set(['Alamitos']),
#  'Alamos': set(['Calle de Los Alamos']),
#  'Alaska': set(['Alaska']),
#  'Albercon': set(['Avenida Albercon']),
#  'Alder': set(['Alder', 'Speckled Alder']),
#  'Alderwood': set(['Alderwood']),
#  'Alegre': set(['Via Alegre']),
#  'Alegria': set(['Alegria']),
#  'Alessandro': set(['West Avenida Alessandro']),
#  'Alevera': set(['Alevera']),
#  'Algodon': set(['Avenida Algodon']),
#  'Alhambra': set(['Alhambra']),
#  'Alicia': set(['Via Alicia']),
#  'Alisos': set(['Camino Alisos']),
#  'Allegheny': set(['Allegheny']),
#  'Allium': set(['Allium']),
#  'Almondwood': set(['Almondwood']),
#  'Almonte': set(['Via Almonte']),
#  'Alonda': set(['Alonda']),
#  'Alondra': set(['Alondra', 'Calle Alondra']),
#  'Altamira': set(['Via Altamira']),
#  'Altazano': set(['Camino Altazano']),
#  'Alter': set(['Alter']),
#  'Amapola': set(['Avenida Amapola']),
#  'Amargosa': set(['Amargosa']),
#  'Amberhill': set(['Amberhill']),
#  'Ambiance': set(['Ambiance']),
#  'Ambiente': set(['Avenida Ambiente']),
#  'Amigos': set(['Los Amigos']),
#  'Amistad': set(['Amistad']),
#  'Amo': set(['Via de Amo']),
#  'Anacapa': set(['Anacapa']),
#  'Andalucia': set(['Andalucia']),
#  'Andante': set(['Del Andante']),
#  'Andirons': set(['Andirons']),
#  'Andrews': set(['Andrews']),
#  'Angel': set(['Via del Angel']),
#  'Angelo': set(['San Angelo']),
#  'Antietam': set(['Antietam']),
#  'Antonio': set(['Antonio', 'West Avenida San Antonio']),
#  'Anzio': set(['Anzio']),
#  'Apple': set(['Red Apple']),
#  'Appleton': set(['Appleton']),
#  'Appomattox': set(['Appomattox']),
#  'Aragon': set(['Avenida Aragon']),
#  'Arboleda': set(['Paseo Arboleda']),
#  'Arboles': set(['Avenida De Los Arboles',
#                  'E Avenida De Los Arboles',
#                  'Paseo de Los Arboles']),
#  'Arbor': set(['Glen Arbor', 'Grape Arbor', 'Shady Arbor']),
#  'Arboretum': set(['Arboretum']),
#  'Arborglen': set(['Arborglen']),
#  'Arborwood': set(['Arborwood']),
#  'Arcata': set(['Arcata']),
#  'Arco': set(['Calle del Arco']),
#  'Ardmore': set(['Ardmore']),
#  'Arenal': set(['Calle Arenal']),
#  'Aria': set(['Aria']),
#  'Arizona': set(['Arizona']),
#  'Arlington': set(['Arlington']),
#  'Arno': set(['Plaza del Arno']),
#  'Arrowhead': set(['Arrowhead']),
#  'Arroyo': set(['Camino Arroyo', 'Paseo del Arroyo', 'Via Arroyo']),
#  'Arroyos': set(['Cinco Arroyos']),
#  'Asbury': set(['Asbury']),
#  'Ascot': set(['Ascot']),
#  'Ash': set(['Maple Ash']),
#  'Ashbrook': set(['Ashbrook']),
#  'Ashdale': set(['Ashdale']),
#  'Ashfield': set(['Ashfield']),
#  'Ashford': set(['Ashford']),
#  'Ashwood': set(['Ashwood']),
#  'Aspenwood': set(['Aspenwood']),
#  'Atascadero': set(['Atascadero']),
#  'Atherton': set(['Atherton']),
#  'Atlanta': set(['Atlanta']),
#  'Atwater': set(['Atwater']),
#  'Augusta': set(['Augusta']),
#  'Autry': set(['Autry']),
#  'Autumn': set(['Autumn']),
#  'Autumnwood': set(['Autumnwood']),
#  'Av': set(['10280 Slater Av',
#             '1341 Euclid St @Trask Av',
#             '4655 Lampson Av',
#             'Orangethorpe Av @ Magnolia Av',
#             'Se Cnr Sr 55 & Lincoln Av']),
#  'Avalon': set(['Avalon', 'I-105 @  Avalon']),
#  'Ave': set(['10th Ave',
#              '12th Ave',
#              '13th Ave',
#              '15887 Grand Ave',
#              '17600 Collier Ave',
#              '20830 Vermont Ave',
#              '210 N Mayflower Ave',
#              '24151 Newhall Ave',
#              '2nd Ave',
#              '3321 Chino Ave',
#              '3rd Ave',
#              '4385 Farmdale Ave',
#              '466 W. Highland Ave',
#              '5th Ave',
#              '718 S Azusa Ave',
#              '8152 Mcfadden Ave',
#              '850 S Baldwin Ave',
#              '8th Ave',
#              '9th Ave',
#              'Alabama Ave',
#              'Alder Ave',
#              'Alderwood Ave',
#              'Amberwood Ave',
#              'Amethyst Ave',
#              'Apple Ave',
#              'Approach Ave',
#              'Arcadia Ave',
#              'Archibald Ave',
#              'Arrowood Ave',
#              'Ashford Ave',
#              'Aspen Ave',
#              'Atlanta Ave',
#              'Atlantic Ave',
#              'Baker Ave',
#              'Balboa Ave',
#              'Banyon Ave',
#              'Bay Ave',
#              'Baylor Ave',
#              'Bellegrave Ave',
#              'Benson Ave',
#              'Bison Ave',
#              'Bohnert Ave',
#              'Bon View Ave',
#              'Bradshawe Ave',
#              'Brookside Ave',
#              'Buffalo Ave',
#              'Cactus Ave',
#              'Calabash Ave',
#              'Camino Real Ave',
#              'Campus Ave',
#              'Candlewood Ave',
#              'Cantabria Ave',
#              'Carlos Ave',
#              'Carpenter Ave',
#              'Cartilla Ave',
#              'Caspian Ave',
#              'Cedar Ave',
#              'Center Ave',
#              'Centinela Ave',
#              'Central Ave',
#              'Ceres Ave',
#              'Cesar E Chavez Ave',
#              'Chapman Ave',
#              'Charles Smith Ave',
#              'Cherry Ave',
#              'Chino Ave',
#              'Church Ave',
#              'Citrus Ave',
#              'Clark Ave',
#              'Cleveland Ave',
#              'College Park Ave',
#              'Colonial Ave',
#              'Coltrane Ave',
#              'Corona Valley Ave',
#              'Cottonwood Ave',
#              'Crosswind Ave',
#              'Cypress Ave',
#              'Dakota Ave',
#              'Del Mar Ave',
#              'Driftwood Ave',
#              'Durfee Ave',
#              'E Citrus Ave',
#              'E Los Angeles Ave',
#              'E Ontario Ave',
#              'E Wellington Ave',
#              'E. Vineyard Ave',
#              'East Ave',
#              'East Katella Ave',
#              'East Los Angeles Ave',
#              'East Naomi Ave',
#              'East Walnut Ave',
#              'Eastern Ave',
#              'Edinger Ave',
#              'Edison Ave',
#              'Eldora Ave',
#              'Empire Ave',
#              'Ethel Ave',
#              'Etiwanda Ave',
#              'Eucalyptus Ave',
#              'Euclid Ave',
#              'Evergreen Ave',
#              'Excise Ave',
#              'Fair Oaks Ave',
#              'Fairview Ave',
#              'Fern Ave',
#              'Fetterly Ave',
#              'Fitzsimmons Ave',
#              'Forest Ave',
#              'Franklin Ave',
#              'Gale Ave',
#              'Garfield Ave',
#              'Glencoe Ave',
#              'Glendal Ave',
#              'Glendora Ave',
#              'Goldenrod Ave',
#              'Granada Ave',
#              'Grove Ave',
#              'Hamner Ave',
#              'Harkness Ave',
#              'Harrison Ave',
#              'Harvard Ave',
#              'Haven Ave',
#              'Hellman Ave',
#              'Hemlock Ave',
#              'Henry Ford Ave',
#              'Hermosa Ave',
#              'Highland Ave',
#              'Hillhurst Ave',
#              'Holliston Ave',
#              'Huntington Garden Ave',
#              'Ilex Ave',
#              'Indiana Ave',
#              'Inglewood Ave',
#              'Iowa Ave',
#              'Iris Ave',
#              'Ironbark Ave',
#              'Iroquois Ave',
#              'Jurupa Ave',
#              'Katella Ave',
#              'Kedge Ave',
#              'Kew Ave',
#              'Kimball Ave',
#              'La Palma Ave',
#              'La Sierra Ave',
#              'Lancewood Ave',
#              'Lantana Ave',
#              'Le Conte Ave',
#              'Lemon Ave',
#              'Lincoln Ave',
#              'Live Oak Ave',
#              'Locust Ave',
#              'London Ave',
#              'Longden Ave',
#              'Loraine Ave',
#              'Los Angeles Ave',
#              'Lugonia Ave',
#              'Lyons Ave',
#              'Magnolia Ave',
#              'Maine Ave',
#              'Malven Ave',
#              'Mango Ave',
#              'Manhattan Beach Ave',
#              'Maple Ave',
#              'Mayberry Ave',
#              'Meadowhouse Ave',
#              'Metropole Ave',
#              'Michigan Ave',
#              'Mildred Ave',
#              'Miller Ave',
#              'Milliken Ave',
#              'Mills Ave',
#              'Montana Ave',
#              'Monte Vista Ave',
#              'Mountain Ave',
#              'N Allen Ave',
#              'N Ashwood Ave',
#              'N Azusa Ave',
#              'N Citrus Ave',
#              'N Columbus Ave',
#              'N Commonwealth Ave',
#              'N Glendale Ave',
#              'N Moss Ave',
#              'N Raymond Ave',
#              'N Van Ness Ave',
#              'N Ventura Ave',
#              'N Victory Ave',
#              'N Western Ave',
#              'Naomi Ave',
#              'Nelson Ave',
#              'Newcastle Ave',
#              'Newhal Ave',
#              'Newhall Ave',
#              'Normandie Ave',
#              'North Allen Ave',
#              'North Fair Oaks Ave',
#              'North Lemon Ave',
#              'North Raymond Ave',
#              'North Rose Ave',
#              'North Tustin Ave',
#              'Norton Ave',
#              'Oaks Ave',
#              'Ocean Ave',
#              'Ohio Ave',
#              'Olive Ave',
#              'Ontario Ave',
#              'Orange Ave',
#              'Orangethorpe Ave',
#              'Orchid Ave',
#              'Oso Ave',
#              'Pacific Ave',
#              'Palm Ave',
#              'Petit Ave',
#              'Phil Ochs Ave',
#              'Pier Ave',
#              'Pine Ave',
#              'Pointe Ave',
#              'Ponderosa Ave',
#              'Proforma Ave',
#              'Puente Ave',
#              'Quince Ave',
#              'Radford Ave',
#              'Ramona Ave',
#              'Rancho Ave',
#              'Redwood Ave',
#              'Remington Ave',
#              'River Ave',
#              'Riverside Ave',
#              'Rochester Ave',
#              'Rose Ave',
#              'Rosecrans Ave',
#              'S Centinela Ave',
#              'S Chapel Ave',
#              'S Glendora Ave',
#              'S Grand Ave',
#              'S Lake Ave',
#              'S Mariposa Ave',
#              'S Victoria Ave',
#              'S Webster Ave',
#              'S. Atlantic Ave',
#              'S. Flower Ave',
#              'S. Vermont Ave',
#              'San Antonio Ave',
#              'San Francisco Ave',
#              'San Gorgonio Ave',
#              'Sandalwood Ave',
#              'Santa Ana Ave',
#              'Santa Anita Ave',
#              'Saybrook Ave',
#              'Schaefer Ave',
#              'Sequoia Ave',
#              'Sierra Ave',
#              'Sierra Madre Ave',
#              'Slover Ave',
#              'Smoke Tree Ave',
#              'Smoketree Ave',
#              'South Beaudry Ave',
#              'South Catalina Ave',
#              'South Fair Oaks Ave',
#              'South Fairfax Ave',
#              'South Freemont Ave',
#              'South Victoria Ave',
#              'South Western Ave',
#              'Sr 57 / S Of Temple Ave',
#              'Star Ruby Ave',
#              'Starfighter Ave',
#              'Sultana Ave',
#              'Summit Ave',
#              'Sungold Ave',
#              'Superior Ave',
#              'Sw Quad Sr 134 / Sr 2 Ic Off E Wilson Ave',
#              'Taft Ave',
#              'Tamarack Ave',
#              'Tamarind Ave',
#              'Taylor Ave',
#              'Telephone Ave',
#              'Temple Ave',
#              'Termino Ave',
#              'Terracina Ave',
#              'Towne Ave',
#              'Tubeway Ave',
#              'Turner Ave',
#              'Turnstone Ave',
#              'Tyrone Ave',
#              'University Ave',
#              'Utica Ave',
#              'Valinda Ave',
#              'Valley Meadow Ave',
#              'Valley View Ave',
#              'Ventura Ave',
#              'Verbena Ave',
#              'Verdugo Ave',
#              'Vermont Ave',
#              'Via Verde Ave',
#              'Villanova Ave',
#              'Vine Ave',
#              'Vineland Ave',
#              'Vineyard Ave',
#              'Virginia Ave',
#              'W Clark Ave',
#              'W Colton Ave',
#              'W Orange Ave',
#              'W. Clary Ave',
#              'W. Commonwealth Ave',
#              'W. Lincoln Ave',
#              'Walnut Ave',
#              'Warner Ave',
#              'Watseka Ave',
#              'West Alameda Ave',
#              'West Capman Ave',
#              'West Lincoln Ave',
#              'White Oak Ave',
#              'Whittier Ave',
#              'Whittram Ave',
#              'Wilson Ave',
#              'Windsor Ave',
#              'Wineville Ave',
#              'Wistaria Ave',
#              'Wisteria Ave',
#              'Woodruff Ave',
#              'Ximeno Ave',
#              'Yale Ave',
#              'Yorba Ave']),
#  'Ave,': set(['Marlton Ave,', 'S. Flower Ave,']),
#  'Ave.': set(['College Ave.',
#               'East Chapman Ave.',
#               'East Ocean Ave.',
#               'Garfield Ave.',
#               'Harbor Ave.',
#               'Lampson Ave.',
#               'Mayberry Ave.',
#               'Muscatel Ave.',
#               'N Pennsylvania Ave.',
#               'N. Glendora Ave.',
#               'North Fair Oaks Ave.',
#               'North Hill Ave.',
#               'North Pass Ave.',
#               'Ocean Ave.',
#               'Rosecrans Ave.',
#               'S. Barranca Ave.',
#               'S. Bradford Ave.',
#               'S. Lake Ave.',
#               'Sierra Ave.',
#               'Tamarack Ave.',
#               'W. Holt Ave.',
#               'West Katella Ave.']),
#  'Aventura': set(['Aventura']),
#  u'Ave\u200e': set([u'E Chapman Ave\u200e']),
#  'Avondale': set(['Avondale']),
#  'Azalea': set(['Azalea']),
#  'Azul': set(['Del Azul']),
#  'BLVD': set(['CRENSHAW BLVD']),
#  'Balcony': set(['Balcony']),
#  'Ballard': set(['Ballard']),
#  'Balsa': set(['Calle Balsa']),
#  'Balsawood': set(['Balsawood']),
#  'Bamboo': set(['Bamboo']),
#  'Bancal': set(['Avenida Bancal']),
#  'Bancroft': set(['Bancroft']),
#  'Banderas': set(['Avenida De Las Banderas']),
#  'Banting': set(['Banting']),
#  'Banyan': set(['Banyan']),
#  'Barbara': set(['Avenida Santa Barbara']),
#  'Barcelona': set(['Avenida Barcelona']),
#  'Barhaven': set(['Barhaven']),
#  'Baritone': set(['Baritone']),
#  'Barrel': set(['Oak Barrel']),
#  'Bay': set(['Bodega Bay', 'Emerald Bay', 'Morro Bay']),
#  'Bayside': set(['Bayside']),
#  'Bayview': set(['Bayview']),
#  'Bd.': set(['Ocean Bd.']),
#  'Beacon': set(['Beacon']),
#  'Beechmont': set(['Beechmont']),
#  'Belcanto': set(['Belcanto']),
#  'Belcrest': set(['Belcrest']),
#  'Bell': set(['Bell']),
#  'Bellevue': set(['Bellevue']),
#  'Bellezza': set(['Bellezza']),
#  'Belmonte': set(['Belmonte', 'Via Belmonte']),
#  'Benchmark': set(['Benchmark']),
#  'Bendix': set(['Bendix']),
#  'Benicia': set(['Benicia']),
#  'Benjamin': set(['Benjamin']),
#  'Bennington': set(['Bennington']),
#  'Berkeley': set(['Berkeley']),
#  'Berkshire': set(['Berkshire']),
#  'Berry': set(['Olde Berry']),
#  'Berth': set(['Berth']),
#  'Besar': set(['Camino Besar']),
#  'Bianco': set(['Bianco']),
#  'Birchwood': set(['Birchwood']),
#  'Bird': set(['Shore Bird']),
#  'Birendra': set(['Birendra']),
#  'Birmingham': set(['Birmingham']),
#  'Bitterwood': set(['Bitterwood']),
#  'Bixby': set(['Bixby']),
#  'Bl': set(['Forest Park Bl', 'Rainbow Valley Bl']),
#  'Bl.': set(['National Bl.']),
#  'Blackbird': set(['Blackbird']),
#  'Blackstone': set(['Blackstone']),
#  'Blakeley': set(['Blakeley']),
#  'Blanco': set(['Blanco', 'Sierra Blanco']),
#  'Blaze': set(['Blaze']),
#  'Blazewood': set(['Blazewood']),
#  'Bloom': set(['Cactus Bloom',
#                'Desert Bloom',
#                'Hedge Bloom',
#                'Last Bloom',
#                'Scarlet Bloom',
#                'Violet Bloom']),
#  'Bloomington': set(['Bloomington']),
#  'Blossom': set(['Blossom', 'White Blossom']),
#  'Bluebell': set(['Bluebell']),
#  'Bluecoat': set(['Bluecoat']),
#  'Bluejay': set(['Bluejay']),
#  'Blv': set(['Brea Blv']),
#  'Blvd': set(['100 N Diamond Bar Blvd',
#               '101 N Diamond Bar Blvd',
#               '1100 Harvard Blvd',
#               '11000 National Blvd',
#               '1250 Van Buren Blvd',
#               '20 E Grand Blvd',
#               '2733 South Sepulveda Blvd',
#               '515 N Beacon @ N Harbor Blvd',
#               '5660 Reseda Blvd',
#               '7300 East Bandini Blvd',
#               'Alessandro Blvd',
#               'Alondra Blvd',
#               'Artesia Blvd',
#               'Atlantic Blvd',
#               'Aviation Blvd',
#               'Baldwin Park Blvd',
#               'Beach Blvd',
#               'Bellflower Blvd',
#               'Beverly Blvd',
#               'Calimesa Blvd',
#               'Crenshaw Blvd',
#               'Del Mar Blvd',
#               'E Magnolia Blvd',
#               'E Manchester Blvd',
#               'E Thompson Blvd',
#               'East Colorado Blvd',
#               'East Manchester Blvd',
#               'East Palmdale Blvd',
#               'East Washington Blvd',
#               'El Segundo Blvd',
#               'Foothill Blvd',
#               'Hacienda Blvd',
#               'Harbor Blvd',
#               'Hawthorne Blvd',
#               'Hilltop Blvd',
#               'Hollywood Blvd',
#               'Jersey Blvd',
#               'Lakewood Blvd',
#               'Lincoln Blvd',
#               'Long Beach Blvd',
#               'Los Alamitos Blvd',
#               'Los Alisos Blvd',
#               'Mission Blvd',
#               'N Indian Hill Blvd',
#               'N Lakewood Blvd',
#               'Newport Blvd',
#               'North Brea Blvd',
#               'North Cahuenga Blvd',
#               'North Robertson Blvd',
#               'Ontario Blvd',
#               'Palos Verdes Blvd',
#               'Paramount Blvd',
#               'Pico Blvd',
#               'Pioneer Blvd',
#               'Ramona Blvd',
#               'Robertson Blvd',
#               'Rosemead Blvd',
#               'S Harbor Blvd',
#               'S La Cienega Blvd',
#               'S San Fernando Blvd',
#               'S Sepulveda Blvd',
#               'San Fernando Mission Blvd',
#               'San Gabriel Blvd',
#               'Santa Monica Blvd',
#               'Sepulveda Blvd',
#               'South Hacienda Blvd',
#               'South Sepulveda Blvd',
#               'Sunset Blvd',
#               'Thompson Blvd',
#               'Topanga Canyon Blvd',
#               'Torrance Blvd',
#               'Universal Studios Blvd',
#               'Valencia Blvd',
#               'Valley Blvd',
#               'Van Buren Blvd',
#               'Venice Blvd',
#               'Ventura Blvd',
#               'Verdugo Blvd',
#               'W Century Blvd',
#               'W Foothill Blvd',
#               'W Gardena Blvd',
#               'W Magnolia Blvd',
#               'W Pico Blvd',
#               'W Redlands Blvd',
#               'W Sunset Blvd',
#               'W Ventura Blvd',
#               'W Washington Blvd',
#               'W. Century Blvd',
#               'Washington Blvd',
#               'West California Blvd',
#               'West Coast Blvd',
#               'West Foothill Blvd',
#               'West Magnolia Blvd',
#               'West Redondo Beach Blvd',
#               'West Valencia Blvd',
#               'West Valley Blvd',
#               'Whittier Blvd',
#               'Wilshire Blvd',
#               'Wishire Blvd',
#               'Yorba Linda Blvd',
#               'Yucaipa Blvd']),
#  'Blvd.': set(['1250 Bellflower Blvd.',
#                '32821 Hilltop Blvd.',
#                'Artesia Blvd.',
#                'Avalon Blvd.',
#                'Beach Blvd.',
#                'Brea Blvd.',
#                'California Blvd.',
#                'E. Colorado Blvd.',
#                'E. Foothill Blvd.',
#                'E. Redlands Blvd.',
#                'East Colorado Blvd.',
#                'East Palmdale Blvd.',
#                'East Thompson Blvd.',
#                'East Washington Blvd.',
#                'Foothill Blvd.',
#                'Harbor Blvd.',
#                'Hawthorne Blvd.',
#                'Jefferson Blvd.',
#                'Lomita Blvd.',
#                'Mission Oaks Blvd.',
#                'N. Rosemead Blvd.',
#                'North Brea Blvd.',
#                'North Robertson Blvd.',
#                'Olympic Blvd.',
#                'Palos Verdes Blvd.',
#                'Rosemead Blvd.',
#                'S Brea Blvd.',
#                'Santa Monica Blvd.',
#                'South Brea Blvd.',
#                'South Diamond Bar Blvd.',
#                'South Harbor Blvd.',
#                'Torrance Blvd.',
#                'W. Foothill Blvd.',
#                'W. Valley Blvd.',
#                'West Balboa Blvd.',
#                'West Olympic Blvd.',
#                'West Redondo Beach Blvd.',
#                'Wilshire Blvd.']),
#  'Boda': set(['Boda']),
#  'Bolas': set(['Calle Las Bolas']),
#  'Bolero': set(['Calle Bolero']),
#  'Bombay': set(['Bombay']),
#  'Bonita': set(['Sierra Bonita']),
#  'Bonsall': set(['Bonsall']),
#  'Boone': set(['Boone']),
#  'Borghese': set(['Borghese']),
#  'Borrego': set(['Borrego']),
#  'Botanical': set(['Botanical']),
#  'Bottlebrush': set(['Bottlebrush']),
#  'Bouleva': set(['Lankershim Bouleva']),
#  'Boulvard': set(['North Brea Boulvard']),
#  'Bowditch': set(['Bowditch']),
#  'Boxwood': set(['Boxwood']),
#  'Bradford': set(['Bradford']),
#  'Bragg': set(['Bragg']),
#  'Brandywine': set(['Brandywine']),
#  'Brava': set(['Costa Brava']),
#  'Breeze': set(['Gentle Breeze']),
#  'Breezes': set(['Breezes']),
#  'Brena': set(['Brena']),
#  'Briarcroft': set(['Briarcroft']),
#  'Bridgeport': set(['Bridgeport']),
#  'Brillantez': set(['Brillantez']),
#  'Brindisi': set(['Brindisi']),
#  'Brittany': set(['Rue Brittany']),
#  'Broadleaf': set(['Broadleaf']),
#  'Broadway': set(['Broadway',
#                   'East Broadway',
#                   'N. Broadway',
#                   'North Broadway',
#                   'South Broadway',
#                   'W. Broadway',
#                   'West Broadway',
#                   'east Broadway']),
#  'Brockton': set(['Brockton']),
#  'Bronze': set(['Bronze']),
#  'Brookdale': set(['Brookdale']),
#  'Brookfield': set(['Brookfield']),
#  'Brookhaven': set(['Brookhaven']),
#  'Brookhollow': set(['Brookhollow']),
#  'Brookmont': set(['Brookmont']),
#  'Brookside': set(['Brookside']),
#  'Brown': set(['Parson Brown']),
#  'Brush': set(['Coyote Brush']),
#  'Buchanan': set(['Buchanan']),
#  'Buck': set(['Spring Buck']),
#  'Buckwood': set(['Buckwood']),
#  'Buellton': set(['Buellton']),
#  'Bumblebee': set(['Bumblebee']),
#  'Bungalow': set(['Bungalow']),
#  'Bunsen': set(['Bunsen']),
#  'Burbank': set(['Burbank']),
#  'Buren': set(['Van Buren']),
#  'Burgoyne': set(['Burgoyne']),
#  'Burke': set(['Burke']),
#  'Burlingame': set(['Burlingame']),
#  'Burroughs': set(['Burroughs']),
#  'Busca': set(['Calle Busca']),
#  'Bush': set(['Quail Bush', 'Salt Bush']),
#  'Bvd': set(['Santa Monica Bvd']),
#  'C': set(['C', 'Santa Monica Boulevard #C', 'W Macarthur Blvd, Ste C']),
#  'CA': set(['9600 Wilshire Blvd, Beverly Hills, CA',
#             '9634 Wilshire Blvd, Beverly Hills, CA',
#             'Sessums Drive, Redlands, CA']),
#  'CA-74': set(['CA-74']),
#  'Caballeros': set(['Paseo De Valencia @ Calle De Los Caballeros']),
#  'Cabot': set(['Cabot']),
#  'Cabrillo': set(['Avenida Cabrillo', 'Calle Cabrillo']),
#  'Cabriole': set(['Cabriole']),
#  'Cactus': set(['Cactus']),
#  'Cadiz': set(['West Avenida Cadiz']),
#  'Cagney': set(['Cagney']),
#  'Cajon': set(['El Cajon']),
#  'Calais': set(['Calais']),
#  'Calandria': set(['Calandria']),
#  'Calderon': set(['Calderon']),
#  'Calhoun': set(['Calhoun']),
#  'Calistoga': set(['Calistoga']),
#  'Cam': set(['Vista Valle Cam']),
#  'Cambridge': set(['Cambridge']),
#  'Camden': set(['Camden']),
#  'Camelia': set(['Camelia']),
#  'Camellia': set(['Camellia']),
#  'Cameron': set(['Cameron']),
#  'Caminata': set(['Calle Caminata']),
#  'Camino': set(['Rancho Camino']),
#  'Campana': set(['Avenida Campana']),
#  'Canada': set(['East Canada', 'La Canada', 'West Canada']),
#  'Canal': set(['Canal', 'Grand Canal']),
#  'CanaryCourt': set(['CanaryCourt']),
#  'Candela': set(['Candela']),
#  'Candleberry': set(['Candleberry']),
#  'Candleglow': set(['Candleglow']),
#  'Cannes': set(['Cannes']),
#  'Canoe': set(['Canoe']),
#  'Canon': set(['Boca del Canon', 'N via Canon']),
#  'Canonero': set(['Calle Canonero']),
#  'Canterra': set(['Canterra']),
#  'Cantora': set(['Cantora']),
#  'Capeberry': set(['Capeberry']),
#  'Capistrano': set(['32941 Camino Capistrano',
#                     'Camino Capistrano',
#                     'Capistrano']),
#  'Capri': set(['Buena Capri', 'Capri']),
#  'Caralene': set(['Calle Caralene']),
#  'Caravan': set(['Caravan']),
#  'Caraway': set(['Caraway']),
#  'Cardinal': set(['Cardinal']),
#  'Carlton': set(['Carlton']),
#  'Carlyle': set(['Carlyle']),
#  'Carmichael': set(['Carmichael']),
#  'Carob': set(['Carob']),
#  'Carolwood': set(['Carolwood']),
#  'Carpenteria': set(['Carpenteria']),
#  'Carrotwood': set(['Carrotwood']),
#  'Carson': set(['Carson']),
#  'Carver': set(['Carver']),
#  'Casa': set(['Via de Casa']),
#  'Cashew': set(['Cashew']),
#  'Casino': set(['Calle Casino']),
#  'Cassandra': set(['Via Cassandra']),
#  'Cassidy': set(['Cassidy']),
#  'Caster': set(['Caster']),
#  'Castillo': set(['Castillo']),
#  'Castle': set(['Stone Castle']),
#  'Castlebar': set(['Castlebar']),
#  'Castlebay': set(['Castlebay']),
#  'Castleview': set(['Castleview']),
#  'Castlewood': set(['Castlewood']),
#  'Catalonia': set(['Catalonia']),
#  'Cedars': set(['Tall Cedars']),
#  'Cedarspring': set(['Cedarspring']),
#  'Cedarwood': set(['Cedarwood']),
#  'Celeste': set(['Calle Celeste']),
#  'Centinela': set(['W. Centinela']),
#  'Centralia': set(['Centralia']),
#  'Cerise': set(['El Cerise']),
#  'Cg': set(['Shearer Cg']),
#  'Chadwick': set(['Chadwick']),
#  'Champlain': set(['Champlain']),
#  'Chandon': set(['92 Chandon', 'Chandon']),
#  'Chantilly': set(['Chantilly']),
#  'Chaparral': set(['Via Chaparral']),
#  'Charleston': set(['Charleston']),
#  'Chattanooga': set(['Chattanooga']),
#  'Chestnut': set(['Chestnut']),
#  'Cheyenne': set(['Cheyenne']),
#  'Chianti': set(['Chianti']),
#  'Chiffon': set(['Chiffon']),
#  'Chime': set(['Bell Chime']),
#  'Chinaberry': set(['Chinaberry']),
#  'Choate': set(['Choate']),
#  'Chrysler': set(['Chrysler']),
#  'Churchill': set(['Churchill']),
#  'Cielo': set(['Camino Cielo', 'Via del Cielo']),
#  'Cienega': set(['11555 South La Cienega', 'Cienega']),
#  'Cinnamon': set(['Cinnamon']),
#  'Cintilar': set(['Cintilar']),
#  'Cipres': set(['Paseo Cipres']),
#  'Cipresso': set(['Cipresso']),
#  'Cir': set(['Alexis Cir',
#              'Armour Cir',
#              'Ashcroft Cir',
#              'Augusta Cir',
#              'Cecille Cir',
#              'Cornell Cir',
#              'Craigburn Cir',
#              'Grayhawk Cir',
#              'Knox Cir',
#              'Midnight Rose Cir',
#              'Mills Cir',
#              'Minkler Cir',
#              'Whispering Tree Cir']),
#  'Citadel': set(['Citadel']),
#  'Citron': set(['Citron']),
#  'City': set(['Crescent City']),
#  'Clarion': set(['W Clarion']),
#  'Clark': set(['Clark']),
#  'Claro': set(['Camino Claro']),
#  'Clary': set(['W. Clary']),
#  'Clay': set(['Clay']),
#  'Clemente': set(['San Clemente']),
#  'Clifford': set(['Clifford']),
#  'Cliffwood': set(['Cliffwood']),
#  'Clinton': set(['Clinton']),
#  'Clocktower': set(['Clocktower']),
#  'Cloister': set(['Cloister']),
#  'Cloud': set(['White Cloud']),
#  'Cloudbreak': set(['Cloudbreak']),
#  'Clover': set(['Clover', 'Tree Clover']),
#  'Cnr': set(['Sr-57 @ Lambert Rd Ne Cnr']),
#  'Coca': set(['Coca']),
#  'Cod': set(['Cape Cod']),
#  'Codorniz': set(['Calle Codorniz']),
#  'Coldbrook': set(['Coldbrook']),
#  'Coldharbor': set(['Coldharbor']),
#  'Coleridge': set(['Coleridge']),
#  'Colina': set(['Calle Colina']),
#  'Colinas': set(['Paseo de la Colinas', 'Via Colinas']),
#  'College': set(['N State College']),
#  'Coloma': set(['Coloma']),
#  'Colonial': set(['Colonial']),
#  'Colorado': set(['Colorado']),
#  'Coltrane': set(['Coltrane']),
#  'Columbia': set(['Columbia']),
#  'Columbus': set(['Columbus']),
#  'Commerce': set(['Commerce']),
#  'Commercial': set(['10175 Cedar & 18645 Commercial']),
#  'Commonwealth': set(['Commonwealth']),
#  'Como': set(['Como']),
#  'Companero': set(['Calle de Companero']),
#  'Compass': set(['Compass']),
#  'Conchita': set(['Calle Conchita']),
#  'Conifer': set(['Conifer']),
#  'Connecticut': set(['Connecticut']),
#  'Conservancy': set(['Conservancy']),
#  'Constantine': set(['Constantine']),
#  'Contessa': set(['Contessa']),
#  'Cook': set(['Cook']),
#  'Copperleaf': set(['Copperleaf']),
#  'Coral': set(['Island Coral']),
#  'Coralita': set(['Coralita']),
#  'Cordoba': set(['West Avenida Cordoba']),
#  'Cornell': set(['Cornell']),
#  'Cornflower': set(['Cornflower']),
#  'Cornwallis': set(['Cornwallis']),
#  'Coromande': set(['Coromande']),
#  'Corona': set(['Via Corona', 'Vista Corona']),
#  'Coronado': set(['Camino Del Coronado', 'Coronado']),
#  'Corozal': set(['Corozal']),
#  'Corredor': set(['Calle Corredor']),
#  'Cortina': set(['Caminita Cortina']),
#  'Cortland': set(['Cortland']),
#  'Corto': set(['Via Corto']),
#  'Cottoncloud': set(['Cottoncloud']),
#  'Cozumel': set(['Cozumel']),
#  'Crabapple': set(['Crabapple']),
#  'Crane': set(['Crane']),
#  'Creekwood': set(['Creekwood']),
#  'Crestline': set(['Crestline']),
#  'Crestwick': set(['Crestwick']),
#  'Cristobal': set(['West Paseo de Cristobal']),
#  'Crockett': set(['Crockett']),
#  'Cromwell': set(['Cromwell']),
#  'Crosskey': set(['Crosskey']),
#  'Crosswinds': set(['Crosswinds']),
#  'Cruiser': set(['Cruiser']),
#  'Ct': set(['Almond Grove Ct',
#             'Altair Ct',
#             'Altizer Ct',
#             'Apple Grove Ct',
#             'Atwood Ct',
#             'Barwick Ct',
#             'Bell Ct',
#             'Bella Ct',
#             'Blue Crab Ct',
#             'Blue Mist Ct',
#             'Blue River Ct',
#             'Blue Rock Ct',
#             'Bonnie Brae Ct',
#             'Bradcliff Ct',
#             'Bright Gem Ct',
#             'Bull Thistle Ct',
#             'Butterwood Ct',
#             'Canterwood Ct',
#             'Cari Ct',
#             'Carnoustie Ct',
#             'Caroline Ct',
#             'Caspian Ct',
#             'Clarion Ct',
#             'Clear Canyon Ct',
#             'Coco Ct',
#             'Coralwood Ct',
#             'Cornwall Ct',
#             'Cornwallis Ct',
#             'Dartmouth Ct',
#             'Dolly Ct',
#             'Doral Ct',
#             'Dutch Ct',
#             'El Morado Ct',
#             'Falling River Ct',
#             'Faraday Ct',
#             'Farmborough Ct',
#             'Firehouse Ct',
#             'Gamay Ct',
#             'Gertrudis Ct',
#             'Gingerwood Ct',
#             'Glen Echo Ct',
#             'Granada Ct',
#             'Guinevere Ct',
#             'Hollyheath Ct',
#             'Inverness Ct',
#             'Ironbark Ct',
#             'Karen Ct',
#             'Kenworth Ct',
#             'Kimball Ct',
#             'Kiso Ct',
#             'Knightsbridge Ct',
#             'Knowlwood Ct',
#             'Kourtney Ct',
#             'La Costa Ct',
#             'Lindsay Ct',
#             'Maddox Ct',
#             'Mandeville Ct',
#             'Mare Meadow Ct',
#             'McConnell Ct',
#             'Merlot Ct',
#             'Millenium Ct',
#             'Nicole Ct',
#             'Nut Grove Ct',
#             'Oro Fino Ct',
#             'Orvieto Ct',
#             'Patti Ann Ct',
#             'Pepperdine Ct',
#             'Perkins Ct',
#             'Persimmon Ct',
#             'Poppy View Ct',
#             'Rae Ct',
#             'Rebecca Ryan Ct',
#             'Regis Ct',
#             'Rico Ct',
#             'Rosewood Ct',
#             'Ruby Giant Ct',
#             'Saddlebred Ct',
#             'Sagemont Ct',
#             'Sahalee Ct',
#             'Sherry Ct',
#             'Silver Lakes Ct',
#             'Skokorat Ct',
#             'Sonterra Ct',
#             'Spyglass Ct',
#             'Swiss Ct',
#             'Terp Ct',
#             'Thoroughbred Ct',
#             'Tigerlilly Ct',
#             'Traminer Ct',
#             'Vinita Ct',
#             'White Horse Ct',
#             'Wiggins Ct',
#             'Windflower Ct',
#             'Wine Ct',
#             'Yorba Ct']),
#  'Ctf': set(['Knapps Ctf']),
#  'Ctr.': set(['Peninsula Ctr.']),
#  'Cudahy': set(['Cudahy']),
#  'Cuesta': set(['Se Quad Us 101 / Pleasant Valley / Santa Rosa Rd Ic Off Calle Cuesta']),
#  'Cultivate': set(['Cultivate']),
#  'Cumbres': set(['Via Cumbres']),
#  'Cummings': set(['Cummings']),
#  'Cunningham': set(['Cunningham']),
#  'Cushing': set(['Cushing']),
#  'Cypresswood': set(['Cypresswood']),
#  'D': set(['Jefferson Avenue suite D',
#            'Western Avenue # D',
#            'Yucaipa Blvd. Ste. D']),
#  'Dahlia': set(['Dahlia']),
#  'Daisy': set(['Yellow Daisy']),
#  'Damara': set(['Damara']),
#  'Dandelion': set(['Dandelion']),
#  'Darwin': set(['Darwin']),
#  'Datepalm': set(['Datepalm']),
#  'Davis': set(['Davis']),
#  'Dawn': set(['New Dawn']),
#  'Daybreak': set(['Daybreak']),
#  'Dearborn': set(['Dearborn']),
#  'Decente': set(['Decente']),
#  'Deermont': set(['Deermont']),
#  'Deerpath': set(['Deerpath']),
#  'Delano': set(['Delano']),
#  'Delaware': set(['Delaware']),
#  'Demasia': set(['Demasia']),
#  'Denim': set(['Denim']),
#  'Denison': set(['Denison']),
#  'Derailer': set(['Derailer']),
#  'Descartes': set(['Descartes']),
#  'Devonshire': set(['Devonshire']),
#  'Dewey': set(['Dewey']),
#  'Diagonal': set(['E Los Coyotes Diagonal']),
#  'Diamond': set(['Diamond']),
#  'Diamondback': set(['Diamondback']),
#  'Diamondleaf': set(['Diamondleaf']),
#  'Dinuba': set(['Dinuba']),
#  'Discovery': set(['Discovery']),
#  'Dive': set(['South Disneyland Dive']),
#  'Dollar': set(['Silver Dollar']),
#  'Domani': set(['Domani']),
#  'Donovan': set(['Donovan']),
#  'Doppler': set(['Doppler']),
#  'Dorado': set(['Via el Dorado']),
#  'Dorchester': set(['Dorchester']),
#  'Dove': set(['Gray Dove', 'Morning Dove']),
#  'Dovecreek': set(['Dovecreek']),
#  'Doverwood': set(['Doverwood']),
#  'Dr': set(['10180 Granite Hill Dr',
#             '15080 Rayneta Dr',
#             '16857 Bayview Dr',
#             '42060 North Shore Dr',
#             'Airport Dr',
#             'Alder Dr',
#             'Alta Cuesta Dr',
#             'Arrastra Dr',
#             'Ayala Dr',
#             'Barstow Dr',
#             'Belcanto Dr',
#             'Black Horse Dr',
#             'Blazing Star Dr',
#             'Blue Gum Dr',
#             'Brookside Dr',
#             'Buena Vista Dr',
#             'Carl Boyer Dr',
#             'Carter Dr',
#             'Castle Pines Dr',
#             'Centrelake Dr',
#             'Cerrito Rojo Dr',
#             'Citrus Dr',
#             'Civic Center Dr',
#             'Clementine Dr',
#             'Clemson Dr',
#             'Coffeeberry Dr',
#             'Comstock Dr',
#             'Cool Meadow Dr',
#             'Cottage Grove Dr',
#             'Country Fair Dr',
#             'Dawnview Dr',
#             'Deep Valley Dr',
#             'Diversa Dr',
#             'Dock Dr',
#             'Duesenberg Dr',
#             'Eastern Shore Dr',
#             'Entrada Dr',
#             'Excalibur Dr',
#             'Excelsior Dr',
#             'Fairchild Dr',
#             'Fairview Dr',
#             'Fairway Dr',
#             'Floral Dr',
#             'Getty Center Dr',
#             'Glory Dr',
#             'Greystone Dr',
#             'Hilton Dr',
#             'Huntington Dr',
#             'Huntridge Dr',
#             'Inspiration Dr',
#             'Jack Rabbit Dr',
#             'Johnson Dr',
#             'Jonquil Dr',
#             'Kendall Dr',
#             'La Cadena Dr',
#             'La Deney Dr',
#             'La Gloria Dr',
#             'La Palma Dr',
#             'Lancelot Dr',
#             'Landon Dr',
#             'Lark Dr',
#             'Lido Park Dr',
#             'Manuel Gonzales Dr',
#             'Marbella Dr',
#             'Meadowsweet Dr',
#             'Merion Dr',
#             'Miners Dr',
#             'Mirador Dr',
#             'Mission Park Dr',
#             'Mission Vista Dr',
#             'Morning Glory Dr',
#             'Morning Hills Dr',
#             'Mountain Dr',
#             'Mountain View Dr',
#             'Oak Hill Dr',
#             'Oak Leaf Dr',
#             'Old Trail Dr',
#             'Ontario Mills Dr',
#             'Pepperglen Dr',
#             'Peyton Dr',
#             'Princeton Dr',
#             'Rea Dr',
#             'Redbird Dr',
#             'Riverside Dr',
#             'Rosilyn Dr',
#             'San Gorgonio Dr',
#             'Santina Dr',
#             'Se Quad Sr 118 / Collins Dr Ic Off Arroyo Dr',
#             'Shadow Hills Dr',
#             'Sherwood Dr',
#             'Silverhawk Dr',
#             'Snow Drop Dr',
#             'Spinnaker Dr',
#             'St Andrews Dr',
#             'Stonewood Dr',
#             'Summerset Dr',
#             'Sunnyview Dr',
#             'Sunrise Dr',
#             'Tacoma Dr',
#             'Tiburon Dr',
#             'Town Center Dr',
#             'Valle Vista Dr',
#             'Valles Dr',
#             'Vantis Dr',
#             'Via Bello Dr',
#             'Via Verde Dr',
#             'W Hillcrest Dr',
#             'Wake Forest Dr',
#             'Wilmington Dr',
#             'Windhaven Dr',
#             'Woolwine Dr',
#             'Yale Dr']),
#  'Dr.': set(['1701 W. Valencia Dr.',
#              'Business Center Dr.',
#              'E. Altadena Dr.',
#              'Las Tunas Dr.',
#              'Santa Barbara Dr.']),
#  'Dreamlight': set(['Dreamlight']),
#  'Duane': set(['Duane']),
#  'Ducommun': set(['Ducommun']),
#  'Dulcea': set(['Via Dulcea']),
#  'Dunmore': set(['Dunmore']),
#  'Dunsmore': set(['Dunsmore']),
#  'E': set(['Avenue E',
#            'Century Park E',
#            'W. Main St. Suite E',
#            'West MacArthur Blvd Suite E',
#            'Western Ave Ste E']),
#  'Eaglecreek': set(['Eaglecreek']),
#  'Earhart': set(['Earhart']),
#  'Earlymorn': set(['Earlymorn']),
#  'East': set(['10th Street East',
#               'Century Park East',
#               'Dorchester East',
#               'Jordan East',
#               'Newport Center Drive East',
#               'Palos Verdes Drive East']),
#  'Easthaven': set(['Easthaven']),
#  'Eastway': set(['Sepulveda Eastway']),
#  'Eclipse': set(['Eclipse']),
#  'Edelman': set(['Edelman']),
#  'Edgewood': set(['Edgewood']),
#  'Elderwood': set(['Elderwood']),
#  'Eldorado': set(['Eldorado']),
#  'Electra': set(['Electra']),
#  'Elkwood': set(['Elkwood']),
#  'Ellen': set(['Glen Ellen']),
#  'Ellipse': set(['Ellipse']),
#  'Ellistone': set(['Ellistone']),
#  'Elmdale': set(['Elmdale']),
#  'Elmwood': set(['Elmwood']),
#  'Emory': set(['Emory']),
#  'Enchanted': set(['Enchanted']),
#  'Encina': set(['Encina']),
#  'Encinal': set(['Encinal']),
#  'End': set(['Trail End']),
#  'Endeavor': set(['Endeavor']),
#  'Enterprise': set(['Enterprise']),
#  'Entrada': set(['Via Entrada']),
#  'Equestre': set(['Paseo Equestre']),
#  'Escalones': set(['East Escalones', 'West Escalones']),
#  'Esplanade': set(['Esplanade']),
#  'Estrell': set(['Avenida de Las Estrell']),
#  'Estrella': set(['North Avenida de la Estrella',
#                   'South Avenida de la Estrella']),
#  'Estrellada': set(['Via Estrellada']),
#  'Eucalyptus': set(['Eucalyptus']),
#  'Eureka': set(['Eureka']),
#  'Evensen': set(['Evensen']),
#  'Everett': set(['Everett']),
#  'Exchange': set(['Exchange']),
#  'Exploration': set(['Exploration']),
#  'Fabricante': set(['Avenida Fabricante']),
#  'Fairbanks': set(['Fairbanks']),
#  'Fairdawn': set(['Fairdawn']),
#  'Fairfield': set(['Fairfield']),
#  'Fairgrove': set(['Fairgrove']),
#  'Fairhaven': set(['Fairhaven']),
#  'Fairview': set(['Fairview']),
#  'Falcon': set(['Black Falcon']),
#  'Fallbrook': set(['Fallbrook']),
#  'Fallenwood': set(['Fallenwood']),
#  'Fanlight': set(['Fanlight']),
#  'Fanpalm': set(['Fanpalm']),
#  'Faraday': set(['Faraday']),
#  'Farragut': set(['Farragut']),
#  'Fawn': set(['Fawn']),
#  'Featherwood': set(['Featherwood']),
#  'Feliz': set(['Via Feliz']),
#  'Fellow': set(['Long Fellow']),
#  'Fence': set(['Long Fence']),
#  'Fenway': set(['Fenway']),
#  'Fern': set(['Tree Fern']),
#  'Fernando': set(['San Fernando']),
#  'Fernbank': set(['Fernbank']),
#  'Fieldwood': set(['Fieldwood']),
#  'Fierro': set(['Via Fierro']),
#  'Figueroa': set(['Figueroa', 'S. Figueroa']),
#  'Fillmore': set(['Fillmore']),
#  'Firefly': set(['Firefly']),
#  'Fl': set(['575 Anton Blvd 3rd Fl', 'S Grand Ave, 11th Fl']),
#  'Flametree': set(['Flametree']),
#  'Flatiron': set(['Flatiron']),
#  'Fleming': set(['Fleming']),
#  'Florencia': set(['Avenida Florencia']),
#  'Florera': set(['Calle Florera']),
#  'Flores': set(['Avenida De Las Flores', 'Buena Flores', 'Flores']),
#  'Floresta': set(['Avenida Floresta', 'Via Floresta']),
#  'Flower': set(['Cactus Flower', 'Jewel Flower']),
#  'Follyhatch': set(['Follyhatch']),
#  'Fontaine': set(['Rue Fontaine']),
#  'Forbes': set(['Forbes']),
#  'Forestwood': set(['Forestwood']),
#  'Foxchase': set(['Foxchase']),
#  'Fragrances': set(['Designer Fragrances']),
#  'Francis': set(['Francis']),
#  'Franklin': set(['Franklin']),
#  'Freeland': set(['Freeland']),
#  'Fremont': set(['Fremont']),
#  'Fresco': set(['Fresco']),
#  'Fulton': set(['Fulton']),
#  'Furrow': set(['Furrow']),
#  'Fusco': set(['Vista Fusco']),
#  'G-2': set(['Proforma Ave. Suite G-2', 'South Proforma Avenue. Suite G-2']),
#  'GERALD': set(['GERALD']),
#  'Gables': set(['Gables', 'Twin Gables']),
#  'Gainesmill': set(['Gainesmill']),
#  'Gainsboro': set(['Gainsboro']),
#  'Galeana': set(['Galeana']),
#  'Galena': set(['Galena']),
#  'Gardenia': set(['Gardenia']),
#  'Gardenview': set(['Gardenview']),
#  'Garnet': set(['Garnet']),
#  'Gate': set(['Cannon Gate', 'Iron Gate']),
#  'Gatewood': set(['Gatewood']),
#  'Gavilan': set(['Via del Gavilan']),
#  'Gaviota': set(['Gaviota', 'West Avenida Gaviota']),
#  'Gazebo': set(['Gazebo']),
#  'Gemstone': set(['Gemstone']),
#  'Genoa': set(['Genoa']),
#  'Gentry': set(['Gentry']),
#  'Georgia': set(['Georgia']),
#  'Gettysburg': set(['Gettysburg']),
#  'Gianni-Turco': set(['Via Gianni-Turco']),
#  'Giorgio': set(['Giorgio']),
#  'Giotto': set(['Giotto']),
#  'Glass': set(['Looking Glass']),
#  'Glenhurst': set(['Glenhurst']),
#  'Glenn': set(['Glenn']),
#  'Glenoaks': set(['Glenoaks']),
#  'Glory': set(['Morning Glory']),
#  'Goddard': set(['360 Goddard', 'Goddard']),
#  'Goldenwren': set(['Goldenwren']),
#  'Goldrush': set(['Goldrush']),
#  'Goodyear': set(['Goodyear']),
#  'Goshen': set(['Goshen']),
#  'Grade': set(['Nate Harrison Grade']),
#  'Granada': set(['Avenida Granada', 'Granada']),
#  'Grande': set(['Calle el Toro Grande', 'Potrero Grande']),
#  'Grant': set(['Grant', 'Land Grant']),
#  'Grapevine': set(['Grapevine']),
#  'Grass': set(['Blue Grass', 'Long Grass', 'Needle Grass', 'Prarie Grass']),
#  'Grassblade': set(['Grassblade']),
#  'Grassland': set(['Grassland']),
#  'Greenbank': set(['Greenbank']),
#  'Greenbriar': set(['Greenbriar']),
#  'Greenhill': set(['Greenhill']),
#  'Groveland': set(['Groveland']),
#  'Grovewood': set(['Grovewood']),
#  'Grulla': set(['Avenida de la Grulla']),
#  'Gruta': set(['Calle Gruta']),
#  'Guinevere': set(['Guinevere']),
#  'Gumwood': set(['Gumwood']),
#  'Habitat': set(['Habitat']),
#  'Hacienda': set(['Avenida Hacienda', 'Hacienda']),
#  'Halcones': set(['Calle de Halcones']),
#  'Hallmark': set(['Hallmark']),
#  'Hallwood': set(['Hallwood']),
#  'Halsted': set(['Halsted']),
#  'Hammond': set(['Hammond']),
#  'Hamner': set(['Hamner']),
#  'Hampshire': set(['New Hampshire']),
#  'Hancock': set(['Hancock']),
#  'Hardy': set(['Ed Hardy']),
#  'Harmony': set(['Harmony']),
#  'Harrisburg': set(['Harrisburg']),
#  'Harrison': set(['Harrison']),
#  'Hathaway': set(['Hathaway']),
#  'Haverhill': set(['Haverhill']),
#  'Hawk': set(['Hawk']),
#  'Hawkcreek': set(['Hawkcreek']),
#  'Hawkeye': set(['Hawkeye']),
#  'Hawthorn': set(['Hawthorn']),
#  'Hayward': set(['Hayward']),
#  'Hazelton': set(['Hazelton']),
#  'Hazelwood': set(['Hazelwood']),
#  'Healdsbury': set(['Healdsbury']),
#  'Hearn': set([' West Chick Hearn']),
#  'Hearthstone': set(['Hearthstone']),
#  'Heather': set(['Heather']),
#  'Heatherton': set(['Heatherton']),
#  'Heatherview': set(['Heatherview']),
#  'Heavenly': set(['Heavenly']),
#  'Heirloom': set(['Heirloom']),
#  'Helix': set(['Helix']),
#  'Henna': set(['Henna']),
#  'Henry': set(['Henry']),
#  'Hermosa': set(['Avenida Vista Hermosa', 'Vista Hermosa']),
#  'Herringbone': set(['Herringbone']),
#  'Hibiscus': set(['Hibiscus']),
#  'Hidalgo': set(['Hidalgo']),
#  'Highlander': set(['Highlander']),
#  'Hillcrest': set(['Hillcrest']),
#  'Hillsdale': set(['Hillsdale']),
#  'Hillview': set(['Via Hillview']),
#  'Hindry': set(['Hindry']),
#  'Historic': set(['Historic']),
#  'Hodgenville': set(['Hodgenville']),
#  'Holbrook': set(['Holbrook']),
#  'Holland': set(['Holland']),
#  'Holler': set(['Old Oak Holler']),
#  'Hollinwood': set(['Hollinwood']),
#  'Homecoming': set(['Homecoming']),
#  'Homeland': set(['Homeland']),
#  'Honeyflower': set(['Honeyflower']),
#  'Honeyrose': set(['Honeyrose']),
# ...
#             'Borges St',
#             'Brama St',
#             'Brentstone St',
#             'Brookside St',
#             'Brooktree St',
#             'Bryant St',
#             'Buckeye St',
#             'Buxton St',
#             'C St',
#             'Callita St',
#             'Calvert St',
#             'Candlewood St',
#             'Carnelian St',
#             'Carpenter St',
#             'Carson St',
#             'Cedar St',
#             'Chaparral St',
#             'Cheshire St',
#             'Church St',
#             'Cochran St',
#             'Comly St',
#             'Concannon St',
#             'Concours St',
#             'Cool Springs St',
#             'Craig St',
#             'D St',
#             'Dahlia St',
#             'Dairy St',
#             'Dalton St',
#             'Deodar St',
#             'Desert Springs St',
#             'Dorset St',
#             'Dozier St',
#             'Dunes St',
#             'Durazno St',
#             'E 4th St',
#             'E 59th St',
#             'E Anaheim St',
#             'E Green St',
#             'E Harrison St',
#             'E Holly St',
#             'E Main St',
#             'E State St',
#             'E Willow St',
#             'E. 1st St',
#             'E. Green St',
#             'E. Washington St',
#             'Earlstone St',
#             'Edinboro St',
#             'Elm St',
#             'Emerson St',
#             'Emmerdale St',
#             'Encina St',
#             'Esther St',
#             'Euclid St',
#             'Eugene St',
#             'Evergreen St',
#             'F St',
#             'Fillmore St',
#             'Fisher St',
#             'Folsom St',
#             'Forest Wood St',
#             'Francis St',
#             'G St',
#             'Gabriel Garcia Marquez St',
#             'Garden Park St',
#             'Garden St',
#             'Gates St',
#             'Glen View St',
#             'Gold Dust St',
#             'Golden Trails St',
#             'Goldy St',
#             'Grant St',
#             'H St',
#             'Hamilton St',
#             'Hammel St',
#             'Harrel St',
#             'Harrow St',
#             'Hawthorne St',
#             'Heil Av @ Brookhurst St',
#             'Hungarian St',
#             'Huntington St',
#             'I St',
#             'I-105 / I-110 Jct 117th St & Figueroa St',
#             'I-105 @ Hawthorne Blvd & 111th St',
#             'Iberia St',
#             'Icelandic St',
#             'J St',
#             'Jasmine St',
#             'Jasper St',
#             'Jersey St',
#             'Joshua Tree St',
#             'Jurupa St',
#             'Kingston St',
#             'Lake Springs St',
#             'Lakeshore St',
#             'Leanne St',
#             'Lewis St',
#             'Lincoln St',
#             'Linfield St',
#             'Locust St',
#             'Los Angeles St',
#             'Lowell St',
#             'Main St',
#             'Manzano St',
#             'Mayfield St',
#             'Meadowvale St',
#             'Mesquit St',
#             'Milton St',
#             'Mission St',
#             'Moonriver St',
#             'Morab St',
#             'Morehouse St',
#             'Mustang St',
#             'N 5th St',
#             'N Figueroa St',
#             'N Gower St',
#             'N Moss St',
#             'N Varney St',
#             'N. Eureka St',
#             'Napa St',
#             'New Dock St',
#             'New York St',
#             'Newbury St',
#             'Newhope St',
#             'Nordhoff St',
#             'North Spring St',
#             'Norwegian St',
#             'Oak St',
#             'Olive St',
#             'Onizuka St',
#             'Ortega St',
#             'Palo Alto St',
#             'Paseo Fino St',
#             'Pattison St',
#             'Paul St',
#             'Persimmon St',
#             'Philadelphia St',
#             'Piedmont St',
#             'Pine St',
#             'Port St',
#             'Princeton St',
#             'Richmond St',
#             'Roberds St',
#             'Rotterdam St',
#             'S Main St',
#             'Sagebrush St',
#             'San Jaun St',
#             'San Marino St',
#             'Santa Ana St',
#             'Sapphire St',
#             'Sawyer St',
#             'Shady Tree St',
#             'Sheffield St',
#             'Smithway St',
#             'South Flower St',
#             'Spruce St',
#             'Stafford St',
#             'State St',
#             'Stowell St',
#             'Summit St',
#             'Syracuse St',
#             'Theresa St',
#             'Townsend St',
#             'Tudor St',
#             'Val St',
#             'Valadez St',
#             'Vanderbilt St',
#             'Victoria St',
#             'Violeta St',
#             'Vista St',
#             'W 3rd St',
#             'W Cypress St',
#             'W Main St',
#             'W State St',
#             'W Temple St',
#             'W. 7th St',
#             'W. 8th St',
#             'W. 9th St',
#             'Walnut St',
#             'Wells Spring St',
#             'West 11th St',
#             'West St',
#             'West Wilson St',
#             'Whitewater St',
#             'Wildflower St',
#             'Windchime St',
#             'Zinfandel St']),
#  'St.': set(['1691 Kettering St.',
#              '520 5th St.',
#              'Abelia St.',
#              'Alabama St.',
#              'Benton St.',
#              'Carson St.',
#              'Center St.',
#              'Commercial St.',
#              'Ducommun St.',
#              'E 1st St.',
#              'E. 1st St.',
#              'E. 3rd St.',
#              'E. Commercial St.',
#              'E. Mariposa St.',
#              'E. Mendocino St.',
#              'E. Temple St.',
#              'Fremont St.',
#              'Jackson St.',
#              'Judge John Aiso St.',
#              'Main St.',
#              'N. Alameda St.',
#              'N. Gary St.',
#              'N. Hope St.',
#              'N. Los Angeles St.',
#              'N. Main St.',
#              'N. Spring St.',
#              'Napa St.',
#              'S. Figueroa St.',
#              'S. Flower St.',
#              'S. Los Angeles St.',
#              'S. Main St.',
#              'S. San Pedro St.',
#              'S. Susan St.',
#              'South Almansor St.',
#              'South Bixel St.',
#              'Temple St.',
#              'W. 7th St.',
#              'W. 8th St.',
#              'W. 9th St.',
#              'W. State St.',
#              'W. Temple St.',
#              'Walker St.']),
#  'Staghorn': set(['Staghorn']),
#  'Stanza': set(['Stanza']),
#  'Star': set(['Distant Star']),
#  'Stars': set(['Avenue of Stars', 'Avenue of the Stars']),
#  'Starwood': set(['Starwood']),
#  'Statuary': set(['Statuary']),
#  'Steinway': set(['Steinway']),
#  'Sterling': set(['Sterling']),
#  'Stizza': set(['Stizza']),
#  'Stonegate': set(['Stonegate']),
#  'Stonewall': set(['Stonewall']),
#  'Stowe': set(['Stowe']),
#  'Str': set(['Miramar Str']),
#  'Strand': set(['The Strand']),
#  'Stratford': set(['Stratford']),
#  'Straw': set(['Straw']),
#  'Sttreet': set(['East Plaza Sttreet']),
#  'Studebaker': set(['Studebaker']),
#  'Sueno': set(['Calle de Sueno']),
#  'Suerte': set(['Buena Suerte', 'Via Buena Suerte']),
#  'Summer': set(['Indian Summer']),
#  'Summerdale': set(['Summerdale']),
#  'Summerfield': set(['Summerfield']),
#  'Sumter': set(['Fort Sumter']),
#  'Sun': set(['Rising Sun']),
#  'Sunnyvale': set(['Sunnyvale']),
#  'Sunriver': set(['Sunriver']),
#  'Sureno': set(['Del Sureno']),
#  'Sutton': set(['Sutton']),
#  'Sweetpea': set(['Sweetpea']),
#  'Symphony': set(['Symphony']),
#  'T250': set(['Highway 189, Suite T250']),
#  'Tala': set(['Via Tala']),
#  'Talisman': set(['Talisman']),
#  'Talmadge': set(['Talmadge']),
#  'Tandem': set(['Tandem']),
#  'Tapestry': set(['Tapestry']),
#  'Taylor': set(['Taylor']),
#  'Tearose': set(['Tearose']),
#  'Tecolotlan': set(['Calle Tecolotlan']),
#  'Telegraph': set(['East Telegraph']),
#  'Telstar': set(['Telstar']),
#  'Templeton': set(['Templeton']),
#  'Tenderfoot': set(['Tenderfoot']),
#  'Tennessee': set(['Tennessee']),
#  'Tequila': set(['Via Tequila']),
#  'Terra': set(['Alta Terra']),
#  'Tesla': set(['Tesla']),
#  'Tesoro': set(['Tesoro']),
#  'Texas': set(['Texas']),
#  'Thatch': set(['Thatch']),
#  'Theory': set(['Theory']),
#  'Thibault': set(['Home Genevieve Thibault']),
#  'Thomas': set(['Thomas']),
#  'Thorn': set(['Fire Thorn']),
#  'Thornapple': set(['Thornapple']),
#  'Thornwood': set(['Thornwood']),
#  'Ticonderoga': set(['Ticonderoga']),
#  'Tidewater': set(['Tidewater']),
#  'Tiempos': set(['Buenos Tiempos']),
#  'Tierra': set(['I-210 / Sierra Madre Blvd Ic Btwn Sierra Madre, San Gabriel & La Tierra']),
#  'Timberland': set(['Timberland']),
#  'Tinker': set(['Tinker']),
#  'Tizmin': set(['Tizmin']),
#  'Toledo': set(['Calle Toledo']),
#  'Tomas': set(['Tomas']),
#  'Tonada': set(['Via Tonada']),
#  'Topanga': set(['Topanga']),
#  'Topaz': set(['Topaz']),
#  'Torcido': set(['Calle Torcido']),
#  'Torrance': set(['Pacific Coast Highway Torrance']),
#  'Tory': set(['Tory']),
#  'Toscany': set(['Toscany']),
#  'Townsend': set(['Townsend']),
#  'Trails': set(['Wild Trails']),
#  'Tranquila': set(['Avenida Tranquila']),
#  'Tranquilo': set(['Paseo Tranquilo']),
#  'Traymore': set(['Traymore']),
#  'Treasure': set(['Treasure']),
#  'Trebol': set(['Camino Trebol']),
#  'Tree': set(['Apple Tree',
#               'Bottle Tree',
#               'Cherry Tree',
#               'Lemon Tree',
#               'Peppermint Tree',
#               'Pine Tree',
#               'Plum Tree',
#               'Silk Tree',
#               'Thorn Tree']),
#  'Treehouse': set(['Treehouse']),
#  'Trellis': set(['Painted Trellis']),
#  'Tren': set(['Avenida del Tren']),
#  'Trenton': set(['East Trenton', 'Trenton', 'West Trenton']),
#  'Trevizio': set(['Via Trevizio']),
#  'Triana': set(['Triana']),
#  'Trillium': set(['Trillium']),
#  'Trl': set(['Canterbury Trl', 'Harbour Town Trl', 'Sea Island Trl']),
#  'Trowel': set(['Trowel']),
#  'Truman': set(['Truman']),
#  'Turner': set(['Turner']),
#  'Tweed': set(['Tweed']),
#  'Twiggs': set(['Twiggs']),
#  'Tyler': set(['1299 Galeria @ Tyler']),
#  'US395': set(['US395']),
#  'Umbria': set(['Umbria']),
#  'Unidos': set(['Via Unidos']),
#  'Upland': set(['Upland']),
#  'Utah': set(['Utah']),
#  'Vacaville': set(['Vacaville']),
#  'Valencia': set(['Paseo De Valencia',
#                   'Paseo de Valencia',
#                   'West Avenida Valencia']),
#  'Valente': set(['Valente']),
#  'Valewood': set(['Valewood']),
#  'Vallarta': set(['Via Vallarta']),
#  'Valle': set(['Bonita Valle', 'Via Valle']),
#  'Vallecito': set(['Vallecito']),
#  'Valore': set(['Rue de Valore']),
#  'Vanderbilt': set(['Vanderbilt']),
#  'Vaquero': set(['Avenida Vaquero']),
#  'Vecindad': set(['Calle Vecindad']),
#  'Vecinos': set(['Los Vecinos']),
#  'Velvetleaf': set(['Velvetleaf']),
#  'Venado': set(['Camino del Venado', 'Via del Venado']),
#  'Vendaval': set(['Paseo Vendaval']),
#  'Veneto': set(['Veneto']),
#  'Venida': set(['Via Venida']),
#  'Venture': set(['Venture']),
#  'Veraneo': set(['Avenida Veraneo']),
#  'Verano': set(['Sitio Verano', 'Verano']),
#  'Verde': set(['Calle Oro Verde',
#                'Camino Verde',
#                'Casa Verde',
#                'Paso Oro Verde',
#                'Questa Verde',
#                'Rio Verde',
#                'Via Oro Verde',
#                'Via Verde',
#                'Via del Verde',
#                'Vista Valle Verde',
#                'Vista del Verde']),
#  'Verdura': set(['Paseo Verdura']),
#  'Vereda': set(['Paseo Vereda']),
#  'Vermont': set(['Vermont']),
#  'Vernon': set(['Mount Vernon']),
#  'Versailles': set(['Versailles']),
#  'Viajante': set(['Via Viajante']),
#  'Vicksburg': set(['Vicksburg']),
#  'Victoria': set(['1722 S Victoria', 'Avenida Victoria', 'Royal Victoria']),
#  'Vida': set(['La Buena Vida']),
#  'Viejo': set(['Mission Viejo', 'The Shops at Mission Viejo', 'Via Viejo']),
#  'Viento': set(['Via Viento']),
#  'Vientos': set(['Calle Vientos']),
#  'Villa': set(['Camino Villa']),
#  'Villager': set(['Villager']),
#  'Villoria': set(['Villoria']),
#  'Vinci': set(['Da Vinci']),
#  'Vine': set(['E. Vine', 'Jade Vine', 'Vine']),
#  'Vintage': set(['Vintage']),
#  'Viola': set(['Viola']),
#  'Violet': set(['Mountain Violet', 'Scented Violet']),
#  'Visalia': set(['Visalia']),
#  'Visionary': set(['Visionary']),
#  'Visions': set(['Visions']),
#  'Vuelta': set(['Calle del Vuelta']),
#  'Vw': set(['Kimble Vw']),
#  'WAY': set(['SOUTH BREEZY WAY']),
#  'Wadsworth': set(['Wadsworth']),
#  'Wagon': set(['Wagon']),
#  'Wakefield': set(['Wakefield']),
#  'Wald': set(['Wald']),
#  'Washington': set(['Washington']),
#  'Watercress': set(['Watercress']),
#  'Waterleaf': set(['Waterleaf']),
#  'Waterman': set(['Waterman']),
#  'Waterspout': set(['Waterspout']),
#  'Watson': set(['Watson']),
#  'Wayfarer': set(['Wayfarer']),
#  'Waynesboro': set(['Waynesboro']),
#  'Weathersfield': set(['Weathersfield']),
#  'Weathervane': set(['Weathervane']),
#  'Wellington': set(['Wellington']),
#  'West': set(['Cahuenga Boulevard West',
#               'Christamon West',
#               'City Boulevard West',
#               'Construction Circle West',
#               'Deerwood West',
#               'Dorchester West',
#               'La Cadena Drive West',
#               'North Formosa Avenue West',
#               'Palos Verdes Drive West',
#               'World Way West']),
#  'Western': set(['S Western']),
#  'Westgate': set(['Westgate']),
#  'Westlake': set(['Westlake']),
#  'Westmoreland': set(['Westmoreland']),
#  'Weston': set(['Weston']),
#  'Westover': set(['Westover']),
#  'Westport': set(['Westport']),
#  'Westwood': set(['Westwood']),
#  'Wharf': set(['Fishermans Wharf']),
#  'Whatney': set(['Whatney']),
#  'Wheelbarrow': set(['Wheelbarrow']),
#  'Wheeler': set(['Wheeler']),
#  'Whiteplume': set(['Whiteplume']),
#  'Whitford': set(['Whitford']),
#  'Whitney': set(['Whitney']),
#  'Wicker': set(['Wicker']),
#  'Wickland': set(['Wickland']),
#  'Wildbrook': set(['Wildbrook']),
#  'Williams': set(['Williams']),
#  'Williamsburg': set(['Williamsburg']),
#  'Willowdale': set(['Willowdale']),
#  'Willowhurst': set(['Willowhurst']),
#  'Willowridge': set(['Willowridge']),
#  'Winchester': set(['Winchester']),
#  'Wind': set(['Whispering Wind']),
#  'Windham': set(['Windham']),
#  'Windjammer': set(['Windjammer']),
#  'Windsong': set(['Windsong']),
#  'Windsor': set(['2122 N Windsor', 'Windsor']),
#  'Wonderland': set(['Wonderland']),
#  'Wood': set(['Berkshire Wood']),
#  'Woodhollow': set(['Woodhollow']),
#  'Woodlawn': set(['Woodlawn']),
#  'Woodridge': set(['Woodridge']),
#  'Woods': set(['Berwick Woods']),
#  'Wright': set(['Wright']),
#  'Wrigley': set(['Wrigley']),
#  'Wy': set(['Ashland Wy',
#             'Babbling Brook Wy',
#             'Campus Wy',
#             'Constitution Wy',
#             'Farmall Wy',
#             'Golden Crown Wy',
#             'Greenbluff Wy',
#             'Harvard Wy',
#             'Honeybrook Wy',
#             'Kaiser Wy',
#             'Kenyon Wy',
#             'Marble Wy',
#             'Massy Harris Wy',
#             'Meadows Wy',
#             'Odyssey Wy',
#             'Sebastian Wy',
#             'Silverado Wy',
#             'Silverweed Wy',
#             'Terrapin Wy',
#             'Townsend Wy',
#             'Transportation Wy',
#             'Trojan Wy',
#             'Wagon Creek Wy',
#             'Wallace Wy',
#             'Westcliff Wy',
#             'White Clover Wy',
#             'Wild Horse Wy',
#             'Wooden Gate Wy',
#             'Yellow Rose Wy']),
#  'Wycliffe': set(['Wycliffe']),
#  'Wyndover': set(['Wyndover']),
#  'Wyoming': set(['Wyoming']),
#  'Yankee': set(['Yankee']),
#  'Yorktown': set(['Yorktown']),
#  'Yountville': set(['Yountville']),
#  'Zancas': set(['Via Zancas']),
#  'Zara': set(['Camino Zara', 'Via Zara']),
#  'Zephyr': set(['Zephyr']),
#  'Zinnia': set(['Zinnia']),
#  'Zuma': set(['Zuma']),
#  'access': set(['Santa Monica Pier access']),
#  'ave': set(['Olive ave']),
#  'avenue': set(['South Cochran avenue',
#                 'north la brea avenue',
#                 'veteran avenue']),
#  'bebe': set(['2b bebe']),
#  'blvd': set(['Artesia blvd', 'Sepulveda blvd']),
#  'court': set(['Hillingdon court']),
#  'ct.': set(['Pulsar ct.']),
#  'floor': set(['9600 Wilshire Boulevard, Beverly Hills, CA 90212  5th floor']),
#  'madera': set(['madera']),
#  'road': set(['North Kenter fire road', 'Pine grove road']),
#  'stephens': set([' stephens', 'stephens']),
#  'street': set(['Cochran street', 'North Palm street', 'W. 190th street']),
#  'way': set(['Sherman way'])}
# 1549

# %% [markdown]
# #### Street Names Abbreviated
#
# There was too much inconsistancy in street names. So I changed all the street names to titliesed for (avenue -> Avenue). Also all '.', ',' characters were removed. Also street names like 'Telephone Ave Suite 12' are changed to 'Telephone Avenue Suite 12'.

# %%
# defining varaibles

CREATED_ATTRIBUTES = ['version', 'changeset', 'timestamp', 'user', 'uid']
POSITION_ATTRIBUTES = ['lat', 'lon']
IGNORED_TAGS = ['gnis:ST_num', 'text', 'tiger:Name', 'gnis:id', 'is_in',
    'gnis:feature_type', 'lake:surface_area:acres', 'gnis:county_id', 'iata',
    'stop', 'trees', 'icao', 'gnis:County', 'gnis:county_num', 'name:en', 'gnis:state_id',
    'health_specialty:palliative_medicine', 'tiger:STATEFP', 'name:ru', 'name:uk'
    'wikipedia:en', 'Hardware Store', 'isced', 'reg_ref', 'start_date',
    'reg_name', 'al', 'isced:level', 'source:maxspeed', 'gnis_state_id',
    'undefined', 'int_ref', 'source:ref:note', 'gnis:ST_alpha', 'gnis:feature_id',
    'practice', 'lake:shore_length:miles', 'gnis:edited', 'gnis:freature_id',
    'name:ar', 'cycleway:left', 'import_uuid', 'odbl:note', 'is_in:state',
    'gnis:reviewed', 'name:backward', 'gnis:fcode', 'is_in:country_code',
    'is_in:iso_3166_2', 'name:brand', 'name:pl', 'gnis:st_alpha']

ALIAS_TAGS = ['name_1', 'old_name', 'alt_name', 'name_2', 'place_name', 'loc_name',
    'official_name', 'name_3', 'short_name', 'bridge_name']

ZIPCODE_TAGS = ['addr:postcode', 'tiger:zip_left', 'tiger:zip_left_1', 'tiger:zip_left_2',
    'tiger:zip_left_3', 'tiger:zip_left_4', 'tiger:zip_right', 'tiger:zip_right_1',
    'tiger:zip_right_2', 'tiger:zip_right_3', 'tiger:zip_right_4']

MAPPED_TAGS = {'cosntruction': 'construction', 'construciton': 'construction',
    'EXit_to': 'exit_to', 'note:ref': 'comment', 'source:note': 'source',
    'exit_to:left': 'exit_to', 'exit_to:right': 'exit_to', 'phone': 'contact:phone',
    'maxspeed:forward': 'maxspeed'}

STREET_MAPPING = {
           "St": "Street",
           "St.": "Street",
           "ST": "Street",
           "Sreet" : "Street",
           "street" : "Street",
           "Str" : "Street",
           "road" : "Road",
           "Roadb" : "Road",
           "Rd": "Road",
           "Rd.": "Road",
           "ct." : "Court",
           "Ct" : "Court",
           "Cir" : "Circle",
           "court" : "Court",
           "Ave":"Avenue",
           "Av" :"Avenue",
           "Ave":"Avenue",
           "Ave,":"Avenue",
           "Ave.":"Avenue",
           u"Ave\u200e":"Avenue",
           "ave":"Avenue",
           "avenue":"Avenue",
           "Blv" : "Boulevard",
           "Blvd" : "Boulevard",
           "blvd" : "Boulevard",
           "Blvd." : "Boulevard",
           "BLVD." : "Boulevard",
           "Bd." : "Boulevard",
           "Bl" : "Boulevard",
           "Bl." : "Boulevard",
           "Dr" : "Drive",
           "Dr.": "Drive",
           "Ln" : "Lane",
           "Ln.": "Lane",
           "PL" : "Plaza",
           "Pl" : "Plaza",
           "Pkwy" : "Parkway",
           "Pkwy." : "Parkway",
           "Pky" : "Parkway",
           "Prkwy" : "Parkway",
           "Rte" : "Route",
           "Trails" : "Trail",
           "Trl" : "Trail",
           "way" : "Way",
           "WAY" : "Way",
           "Wy" : "Way",
           "Vw" : "View",
           "Valle" : "Valley"
}

# %%
def shape_element(element):
    node = {}
    created_attributes = CREATED_ATTRIBUTES
    position_attributes = POSITION_ATTRIBUTES
    ignored_tags = IGNORED_TAGS
    alias_tags = ALIAS_TAGS
    zipcode_tags = ZIPCODE_TAGS
    mapped_tags = MAPPED_TAGS
    mapping = STREET_MAPPING

    if element.tag == 'node' or element.tag == 'way':
        
        node['type'] = element.tag

        address = {}
        zipcodes = set()

        for attribute in element.attrib:
            
            if attribute in created_attributes:
                
                if 'created' not in node:
                    node['created'] = {}
                    
                node['created'][attribute] = element.get(attribute)
            elif attribute in position_attributes:
                continue
            else:
                node[attribute] = element.get(attribute)

        if 'lat' in element.attrib and 'lon' in element.attrib:
            node['pos'] = [float(element.get('lat')), float(element.get('lon'))]

        for child in element:

            if child.tag == 'nd':
                if 'node_refs' not in node:
                    node['node_refs'] = []
                if 'ref' in child.attrib:
                    node['node_refs'].append(child.get('ref'))

            if child.tag != 'tag' or 'k' not in child.attrib or 'v' not in child.attrib:
                continue
            key = child.get('k').lower()
            val = child.get('v')

            # skip problematic characters
            if problemchars.search(key):
                continue

            # skip ignored tags
            if key in ignored_tags:
                continue

            # swap keys for corrections
            if key in mapped_tags:
                key = mapped_tags[key]

            if key in zipcode_tags:
                for zipcode in process_zipcode(val):
                    zipcodes.add(zipcode)

            # set all states to CA
            if key == 'addr:state':
                key = 'CA'

            # fix and standardize phone numbers using phonenumbers module and list comprehensions
            if key == 'contact:phone':
                phone_number_matches = [m.number for m in phonenumbers.PhoneNumberMatcher(val, "US")]
                val = ';'.join([phonenumbers.format_number(phone_number_match,
                    phonenumbers.PhoneNumberFormat.NATIONAL)
                    for phone_number_match in phone_number_matches])

            if address_regex.search(key):
                key = key.replace('addr:', '')
                address[key] = val
                continue

            if key in alias_tags:
                if 'aliases' not in node:
                    node['aliases'] = {}
                node['aliases'][key] = val
                continue

            if ':' in key:
                add_branched_item(key, val, node)
                continue

            if key not in node:
                node[key] = val

        if 'name' not in node and 'aliases' in node:
            for alias in alias_tags:
                if alias in node['aliases']:
                    node['name'] = alias
                    break

        if zipcodes:
            node['zipcodes'] = list(zipcodes)

        if len(address) > 0:
            node['address'] = {}
            street_full = None
            street_dict = {}
            street_format = ['prefix', 'name', 'type']

            for key in address:
                val = address[key]
                if street_regex.search(key):
                    if key == 'street':
                        street_full = update_name(val,mapping)
                    elif 'street:' in key:
                        street_dict[key.replace('street:', '')] = val
                else:
                    node['address'][key] = val

            if street_full:
                node['address']['street'] = street_full
            elif len(street_dict) > 0:
                unclean_street = ' '.join([street_dict[key] for key in street_format])
                node['address']['street'] = update_name(unclean_street, mapping)

        return node
    else:
        return None

def update_name(name, mapping):
    
    m = street_type_re.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping.keys():
            better_name = street_type_re.sub(mapping[street_type], name)
        
        if street_type_in_between(name,mapping.keys()):
            key = street_type_in_between(name,mapping.keys())
            better_name = name.replace(key, mapping[key])
        else:
            better_name = name
        return better_name
    else:
        return name

def street_type_in_between(val, mapping_keys):
    
    for key in mapping_keys:
        if key in val:
            return key
    return None

def add_branched_item(key, val, node):

    key_split = key.split(':')
    base = key_split.pop(0)
    remainder = ':'.join(key_split)
    if type(node) == dict:
        if len(key_split) == 0:
            node[base] = val
        else:
            if base not in node:
                node[base] = {}
            add_branched_item(remainder, val, node[base])

def process_zipcode(string):
    result = []
    groups = [group.strip() for group in string.split(';')]
    for group in groups:
        if re.match(r'\d{5}\:\d{5}', group):
            group_range = map(int, group.split(':'))
            result += list(map(str, range(group_range[0], group_range[1]+1)))
        elif re.match(r'\d{5}', group):
            result.append(group)
    return result

def process_map(file_in):
    
    file_out = '{0}.json'.format(file_in)
    with codecs.open(file_out, 'w',encoding='utf-8') as fo:
        print "Writing Starts"
        for _, element in ET.iterparse(file_in):
            
            el = shape_element(element)
            if el:
                fo.write(json.dumps(el))
            element.clear()

        print "Writing Done"

process_map(__OSMFILE__)

# %% [markdown]
# ### Section 2: Data Overview
#
# This section contains basic statistics about the dataset and the MongoDB queries used to gather them.

# %% [markdown]
# ##### File Sizes
#
# los-angeles_california.osm.json : **2.5GB** <br>
# lolos-angeles_california.osm    : **2.5GB**

# %%
connection = pymongo.Connection('localhost',27017)
db = connection.OpenMapStreet
coll = db.losAngelesCA

# %% [markdown]
# ##### Number of Documents

# %%
print coll.count()
# Out:
# 12180466

# %% [markdown]
# ##### Number of nodes and ways

# %%
print 'Nodes : ',coll.find({'type' : 'node'}).count()
print 'Way : ',coll.find({'type' : 'way'}).count()
# Out:
# Nodes :  10955705
# Way :  1224761

# %% [markdown]
# ##### Number of distinct users

# %%
print len(coll.distinct('created.user'))
# Out:
# 3301

# %% [markdown]
# ##### Top 10 Contributing Users

# %%
pprint(coll.aggregate([
        {'$group' : {'_id' : '$created.user', 'count' : {'$sum' : 1}}},
        {'$sort' : {'count' : -1}},
        {'$limit' : 10}
    ]))
# Out:
# {u'ok': 1.0,
#  u'result': [{u'_id': u'schleuss_imports', u'count': 1054163},
#              {u'_id': u'manings_labuildings', u'count': 635592},
#              {u'_id': u'The Temecula Mapper', u'count': 541484},
#              {u'_id': u'woodpeck_fixbot', u'count': 514697},
#              {u'_id': u'AM909', u'count': 447961},
#              {u'_id': u'kingrollo_imports', u'count': 434711},
#              {u'_id': u'nmixter', u'count': 318435},
#              {u'_id': u'N76_import', u'count': 314432},
#              {u'_id': u'SJFriedl', u'count': 263802},
#              {u'_id': u'calfarome_labuilding', u'count': 248838}],
#  u'waitedMS': 0L}

# %% [markdown]
# ##### Number of users contributing only once

# %%
coll.aggregate([
        {'$group' : {'_id' : '$created.user', 'count' : {'$sum' : 1}}},
        {'$group' : {'_id' : '$count', 'num_users' : {'$sum' : 1}}},
        {'$sort' : {'_id' : 1}},
        {'$limit' : 1}
    ])
# Out:
# {u'ok': 1.0, u'result': [{u'_id': 1, u'num_users': 688}], u'waitedMS': 0L}

# %% [markdown]
# ### Section 3: Additional Ideas

# %% [markdown]
# ##### Contributor statistics
#
# * Top user contribution percentage (“schleuss_imports”) : **8.65%** <br>
# * Combined top 2 users' contribution (“schleuss_imports” and “manings_labuildings”) : **13.87%**<br>
# * Combined Top 10 users contribution : **39.19%**<br>
# * Combined contribution of users contributing only once - **0.006%**<br>

# %% [markdown]
# ##### Conclusion
#
# After this review of the data it’s obvious that the **Los Angeles California** area is incomplete, though I believe it has been well cleaned for the purposes of this exercise.
